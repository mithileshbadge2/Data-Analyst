# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gapminder_full.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({'year':'YEAR'},axis=1,inplace=True)

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# for x in range(0,11):
#     print(x**2)
[x**2 for x in range(0,11)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
[x**3 for x in range(2,21)]
# for x in range(2,21):
#     print(x**3)
# Out:
# [8,
#  27,
#  64,
#  125,
#  216,
#  343,
#  512,
#  729,
#  1000,
#  1331,
#  1728,
#  2197,
#  2744,
#  3375,
#  4096,
#  4913,
#  5832,
#  6859,
#  8000]

# %%
df['custom']=[x**2 for x in range(1,1705)]

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap   custom
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030        4
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710        9
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138       16
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106       25
# ...           ...   ...         ...       ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306  2890000
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786  2893401
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960  2896804
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623  2900209
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298  2903616
#
# [1704 rows x 7 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index = df['custom']

# %%
df
# Out:
#              country  YEAR  population continent  life_exp     gdp_cap  \
# custom
# 1        Afghanistan  1952     8425333      Asia    28.801  779.445314
# 4        Afghanistan  1957     9240934      Asia    30.332  820.853030
# 9        Afghanistan  1962    10267083      Asia    31.997  853.100710
# 16       Afghanistan  1967    11537966      Asia    34.020  836.197138
# 25       Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...              ...   ...         ...       ...       ...         ...
# 2890000     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 2893401     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 2896804     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 2900209     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 2903616     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#           custom
# custom
# 1              1
# 4              4
# 9              9
# 16            16
# ...

# %%
df.drop('custom',axis=1,inplace=True)

# %%
df
# Out:
#              country  YEAR  population continent  life_exp     gdp_cap
# custom
# 1        Afghanistan  1952     8425333      Asia    28.801  779.445314
# 4        Afghanistan  1957     9240934      Asia    30.332  820.853030
# 9        Afghanistan  1962    10267083      Asia    31.997  853.100710
# 16       Afghanistan  1967    11537966      Asia    34.020  836.197138
# 25       Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...              ...   ...         ...       ...       ...         ...
# 2890000     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 2893401     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 2896804     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 2900209     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 2903616     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('custom',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.drop('custom',axis=1,inplace=True)
#
# File D:\anaconda\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...
