# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,10,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

fig , ax = plt.subplots(1,3)
ax[0].plot(x,y1)
ax[1].plot(x,y2)
ax[2].plot(x,y3)

# %%
plt.subplots(1,3)
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(1,5)
# Out:
# (<Figure size 640x480 with 5 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(2,5)
# Out:
# (<Figure size 640x480 with 10 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %%
# subplot using objects
x = np.arange(1,10,.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure()
plt.subplot(3,1,1)
plt.plot(x,y1)

plt.subplot(3,1,2)
plt.plot(x,y2)

plt.subplot(3,1,3)
plt.plot(x,y3)

# %%
x = np.arange(1,10,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure()

plt.subplot(1,3,1)
plt.plot(x,y1)

plt.subplot(1,3,2)
plt.plot(x,y2)

plt.subplot(1,3,3)
plt.plot(x,y3)

# %%
x = np.arange(1,10,.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure()

plt.subplot(2,3,1)
plt.plot(x,y1)

plt.subplot(2,3,2)
plt.plot(x,y2)

plt.subplot(2,3,3)
plt.plot(x,y3)

plt.subplot(2,3,4)
plt.plot()

plt.subplot(2,3,5)
plt.plot()

plt.subplot(2,3,6)
plt.plot()
# Out:
# []

# %%
# 3D plotting

a = np.arange(-1,1,0.010)
b = a

a,b = np.meshgrid(a,b)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(a,b,a**2+b**2)
