# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gapminder_full.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.iloc[0:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[999:1011]
# Out:
#          country  year  population continent  life_exp      gdp_cap
# 999     Mongolia  1967     1149500      Asia    51.253  1226.041130
# 1000    Mongolia  1972     1320500      Asia    53.754  1421.741975
# 1001    Mongolia  1977     1528000      Asia    55.491  1647.511665
# 1002    Mongolia  1982     1756032      Asia    57.489  2000.603139
# 1003    Mongolia  1987     2015133      Asia    60.222  2338.008304
# 1004    Mongolia  1992     2312802      Asia    61.271  1785.402016
# 1005    Mongolia  1997     2494803      Asia    63.625  1902.252100
# 1006    Mongolia  2002     2674234      Asia    65.033  2140.739323
# 1007    Mongolia  2007     2874127      Asia    66.803  3095.772271
# 1008  Montenegro  1952      413834    Europe    59.164  2647.585601
# 1009  Montenegro  1957      442829    Europe    61.448  3682.259903
# 1010  Montenegro  1962      474528    Europe    63.728  4649.593785

# %%
df.iloc[0:1704:102]
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 102    Bangladesh  1982    93074406      Asia    50.009   676.981866
# 204       Burundi  1952     2445618    Africa    39.031   339.296459
# 306      Colombia  1982    27764644  Americas    66.653  4397.575659
# 408       Denmark  1952     4334000    Europe    70.780  9692.385245
# 510      Ethiopia  1982    38111756    Africa    44.916   577.860747
# 612        Guinea  1952     2664249    Africa    33.609   510.196492
# 714     Indonesia  1982   153343000      Asia    56.159  1516.872988
# 816         Kenya  1952     6464046    Africa    42.270   853.540919
# 918    Madagascar  1982     9171477    Africa    48.969  1302.878658
# 1020      Morocco  1952     9939217    Africa    42.873  1688.203570
# 1122        Niger  1982     6437188    Africa    42.598   909.722135
# 1224       Poland  1952    25730551    Europe    61.310  4029.329699
# ...

# %%
# reverse
df[::-1]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# ...           ...   ...         ...       ...       ...         ...
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1704 rows x 6 columns]

# %%
# adding rows

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
d = {'country':'India', 'year':2020, 'population':1000000, 'continent':'Asia', 'life_exp':44.11, 'gdp_cap':101.1}

# %%
d
# Out:
# {'country': 'India',
#  'year': 2020,
#  'population': 1000000,
#  'continent': 'Asia',
#  'life_exp': 44.11,
#  'gdp_cap': 101.1}

# %%
# pd.append([df,d],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pd.append([df,d],ignore_index=True)
#
# AttributeError: module 'pandas' has no attribute 'append'

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[1704] = pd.Series(d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.iloc[1704] = pd.Series(d)
#
# File D:\anaconda\Lib\site-packages\pandas\core\indexing.py:846, in _LocationIndexer.__setitem__(self, key, value)
#     844     key = com.apply_if_callable(key, self.obj)
#     845 indexer = self._get_setitem_indexer(key)
# --> 846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
#     849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File D:\anaconda\Lib\site-packages\pandas\core\indexing.py:1550, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1548 elif is_integer(i):
#    1549     if i >= len(ax):
# -> 1550         raise IndexError("iloc cannot enlarge its target object")
#    1551 elif isinstance(i, dict):
#    1552     raise IndexError("iloc cannot enlarge its target object")
#
# ...

# %%
df.loc[1704] = pd.Series(d)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
d1 = {'country':'India', 'year':2024, 'population':1001000, 'continent':'Asia', 'life_exp':47.11, 'gdp_cap':105.1}

# %%
d1
# Out:
# {'country': 'Hindustan',
#  'year': 2024,
#  'population': 45000,
#  'continent': 'Asia',
#  'life_exp': 55.08,
#  'gdp_cap': 8885.03}

# %%
df.loc[1705]=pd.Series(d1)

# %%
df
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1705    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1706 rows x 6 columns]

# %%
# removing duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# 1705    False
# Length: 1706, dtype: bool

# %%
df[df.duplicated()] #there is no TRue value means no duplicates
# Out:
# Empty DataFrame
# Columns: [country, year, population, continent, life_exp, gdp_cap]
# Index: []

# %%
df
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1705    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1706 rows x 6 columns]

# %%
df.loc[1706] = pd.Series(d1)

# %%
df
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1705    Hindustan  2024       45000      Asia    55.080  8885.030000
# 1706    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1707 rows x 6 columns]

# %%
df.loc[1707] = pd.Series(d1)

# %%
df
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1705    Hindustan  2024       45000      Asia    55.080  8885.030000
# 1706    Hindustan  2024       45000      Asia    55.080  8885.030000
# 1708    Hindustan  2024       45000      Asia    55.080  8885.030000
# 1707    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1709 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1704    False
# 1705    False
# 1706     True
# 1708     True
# 1707     True
# Length: 1709, dtype: bool

# %%
df[df.duplicated()]
# Out:
#         country  year  population continent  life_exp  gdp_cap
# 1706  Hindustan  2024       45000      Asia     55.08  8885.03
# 1708  Hindustan  2024       45000      Asia     55.08  8885.03
# 1707  Hindustan  2024       45000      Asia     55.08  8885.03

# %%
df.drop_duplicates() #all 3 duplicates removed
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1705    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1706 rows x 6 columns]

# %%
df.drop_duplicates(keep='last',inplace=True) #duplicates rem 1705&1706

# %%
df
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1707    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1706 rows x 6 columns]

# %%
df.drop(4)
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 5     Afghanistan  1977    14880372      Asia    38.438   786.113360
# ...           ...   ...         ...       ...       ...          ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        India  2020     1000000      Asia    44.110   101.100000
# 1707    Hindustan  2024       45000      Asia    55.080  8885.030000
#
# [1705 rows x 6 columns]

# %%
df.drop(1707,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]
