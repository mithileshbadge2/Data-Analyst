# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# scatter plots

# generating random numbers for plotting

# %%
np.random.rand(10)
# Out:
# array([0.44149131, 0.4903187 , 0.6243124 , 0.50401366, 0.36592626,
#        0.07275547, 0.90645845, 0.1796091 , 0.51787131, 0.30778985])

# %%
np.random.rand(20)
# Out:
# array([0.84628413, 0.49529037, 0.28511541, 0.96202533, 0.21013375,
#        0.55619635, 0.30175747, 0.56004812, 0.67430302, 0.45844341,
#        0.5599433 , 0.97812562, 0.57890553, 0.96498936, 0.17823762,
#        0.91935638, 0.61289007, 0.29133291, 0.42476494, 0.96950337])

# %%
np.random.rand(20)*10
# Out:
# array([7.86681043, 7.59243977, 9.37722336, 4.00919586, 5.85024159,
#        7.65683109, 0.56200891, 0.60019566, 1.2463197 , 8.41441122,
#        7.7161635 , 9.75802407, 0.07233893, 4.31902316, 5.10024362,
#        2.04571228, 1.22591306, 1.41068808, 8.32527807, 5.42877737])

# %%
np.random.rand(20)*10
# Out:
# array([2.1535632 , 8.64410826, 1.1764521 , 1.4085952 , 6.10182143,
#        8.65016625, 0.28017993, 8.75883716, 7.8571888 , 3.04609414,
#        6.47299108, 9.94660841, 5.90446376, 0.23737637, 3.55207768,
#        1.73589219, 8.7783752 , 3.47935474, 6.79307994, 8.52168288])

# %%
x = np.arange(20)
y = np.random.rand(20)*10
plt.scatter(x,y)
plt.show()

# %%
x = np.arange(20)
y = np.linspace(1,20,20) + np.random.rand(20)*10
plt.scatter(x,y)
plt.show()

# %%
# multiple scatter plots
x = np.arange(20)
y1 = np.linspace(1,20,20) + np.random.rand(20)*10
y2 = np.linspace(1,20,20) + np.random.rand(20)*110
plt.scatter(x,y1)
plt.scatter(x,y2)
plt.show()

# %%
# SUBPLOTS
x = np.arange(1,10,.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x = np.arange(1,10,.1)
y = np.tan(x)
plt.plot(x,y)
plt.show()

# %%
x = np.arange(1,10,.1)
y1 = np.sin(x)
plt.plot(x,y1)

y2 = np.tan(x)
plt.plot(x,y2)
plt.show()

# %%
# rearranging the code seq for better readability!!!
x = np.arange(1,10,.1)
y1 = np.sin(x)
y2 = np.tan(x)

plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
# using sub-plots
x = np.arange(1,10,.1)
y1 = np.tan(x)
y2 = np.sin(x)
y3 = np.cos(x)

fig,ax = plt.subplots(1,3)
ax[0].plot(x,y1)
ax[1].plot(x,y2)
ax[2].plot(x,y3)

# %%
# understanding the subplots()
fig , ax = plt.subplots(1,3)

# %%
type(plt.subplots(1,3))
# Out:
# tuple

# %%
tup1 = (100,200,300)
print(tup1[0])
print(tup1[1])
print(tup1[2])
# Out:
# 100
# 200
# 300

# %%
# unpacking of tuple
a,b,c = tup1
print(a)
print(b)
print(c)
# Out:
# 100
# 200
# 300

# %%
plt.subplots(3,1)
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))
