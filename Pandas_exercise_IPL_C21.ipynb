# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# Accessing rows and columns
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['winner','team1','team2']]
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# iloc
data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[:50,[4,5,10]]
# Out:
#                           team1                        team2  \
# 0           Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                Mumbai Indians       Rising Pune Supergiant
# 2                 Gujarat Lions        Kolkata Knight Riders
# 3        Rising Pune Supergiant              Kings XI Punjab
# 4   Royal Challengers Bangalore             Delhi Daredevils
# 5                 Gujarat Lions          Sunrisers Hyderabad
# 6         Kolkata Knight Riders               Mumbai Indians
# 7   Royal Challengers Bangalore              Kings XI Punjab
# 8              Delhi Daredevils       Rising Pune Supergiant
# 9           Sunrisers Hyderabad               Mumbai Indians
# 10              Kings XI Punjab        Kolkata Knight Riders
# 11  Royal Challengers Bangalore               Mumbai Indians
# 12       Rising Pune Supergiant                Gujarat Lions
# 13        Kolkata Knight Riders          Sunrisers Hyderabad
# ...

# %%
# data filtering using fancy indexing ,i.e Boolean Masking

# find no of matches played in bangalore only

mask1 = data['city']=='Bangalore'

# %%
mask1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 631    False
# 632     True
# 633    False
# 634    False
# 635     True
# Name: city, Length: 636, dtype: bool

# %%
type(mask1)
# Out:
# pandas.core.series.Series

# %%
data[mask1]
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 616  617    2016  Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data[mask1])
# Out:
# pandas.core.frame.DataFrame

# %%
data[mask1].shape
# Out:
# (66, 18)

# %%
type(data[mask1].shape)
# Out:
# tuple

# %%
data[mask1].shape[0]
# Out:
# 66

# %%
# Hyderabad
data[data['city']=='Hyderabad'].shape[0]
# Out:
# 49

# %%
data[data['city']=='Rajkot'].shape[0]
# Out:
# 10

# %%
# Applying multiple masks ???

# %%
data['team1']=='Royal Challengers Bangalore'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: team1, Length: 636, dtype: bool

# %%
data[data['team1']=='Royal Challengers Bangalore'].shape[0]
# Out:
# 70

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[data['team2']=='Royal Challengers Bangalore'].shape[0]
# Out:
# 82

# %%
# combined both
data[data['team1']=='Royal Challengers Bangalore'].shape[0]
data[data['team2']=='Royal Challengers Bangalore'].shape[0]
# Out:
# 82

# %%
mask5 = data['team1']=='Royal Challengers Bangalore'
mask6 = data['team2']=='Royal Challengers Bangalore'

# %%
data[mask5 | mask6]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# ..   ...     ...        ...         ...                          ...
# 623  624    2016    Kolkata  2016-05-16        Kolkata Knight Riders
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[mask5 | mask6].shape[0]
# Out:
# 152

# %%
#  no matches played in mumbai after year 2015

# %%
maskA = data['city']=='Mumbai'

# %%
maskB = data['season']>2015

# %%
data[maskA & maskB]
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# 36    37    2017  Mumbai  2017-05-01  Royal Challengers Bangalore
# 49    50    2017  Mumbai  2017-05-11              Kings XI Punjab
# 55    56    2017  Mumbai  2017-05-16       Rising Pune Supergiant
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2                  toss_winner toss_decision  \
# ...

# %%
data[maskA & maskB].shape[0]
# Out:
# 12
